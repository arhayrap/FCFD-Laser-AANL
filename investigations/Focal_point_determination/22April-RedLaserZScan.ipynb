# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
---Setup info---
freq = 10kHz
Red Laser
'''

Z           = [-2000, -1000, 0, 1000, 2000, 3000, 4000, 5000, 6000] # um
AmpMean     = [359, 356, 360, 361, 357, 367, 406, 372, 343]
AmpPeak     = [1.84, 1.84, 1.8, 1.8, 1.8, 1.68, 1.28, 1.56, 1.72]
AmpMax      = [1.80, 1.76, 1.76, 1.76, 1.76, 1.64, 1.28, 1.56, 1.68]
RiseTime    = [2.4, 2.35, 2.35, 2.3, 2.4, 2.25, 2.1, 2.4, 2.3]
FallTime    = [111.6, 112.3, 118.8, 124.0, 128.6, 123.7, 154.8, 137.0, 111.3]

# %%
plt.plot(Z, AmpMean)
plt.grid()

# %%
Z           = np.linspace(3000, 5000, 21) # um
AmpMean     = [328, 331, 336, 338, 344, 349, 353, 357, 364, 368, 
               371, 376, 377, 375, 371, 370, 366, 361, 355, 350,
               345]

# %%
# plt.plot(Z[10:-6], AmpMean[10:-6]) #zoomed in
plt.scatter(Z, AmpMean)
plt.grid()
plt.xlabel("Z position [um]")
plt.ylabel("Mean amplitude [mV]")
plt.title("Lens Z position vs mean amplitude")
plt.text(3100, 370, "Focal height: 4200um", color='red', fontweight='bold')
plt.show()
