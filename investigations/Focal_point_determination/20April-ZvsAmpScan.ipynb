# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''pulse frequency = 500Hz'''
'''Data of the Z position scan 1 (Volts are scaled by 10)'''

Z =        [-22000, -12000, -2000, 8000.0, 18000.0, 19773.31] # um
AmpMean  = [1.53, 2.18, 3.09, 3.11, 2.16, 1.97] # V
AmpPeak  = [13.2, 17.6, 19.6, 19.6, 17.2, 16.4] # V
AmpMax   = [12.8, 17.2, 19.2, 19.2, 16.8, 16.0] # V
FallTime = [64.2, 68.6, 85.2, 85.2, 68.4, 63.7] # ns
RiseTime = [2.6, 2.58, 2.82, 2.84, 2.62, 2.46] # ns

# %%
'''Data of the Z position scan 2 (zoom into -2000 to 8000 range)'''

Z =        [-2000, -1000, 0, 1000, 2000, 3000, 4000, 5000, 6000] # um
AmpMean  = [309, 330, 359, 409, 467, 505, 464, 415, 366] # mV
AmpPeak  = [1.96, 1.96, 2.0, 2.04, 2.0, 2.04, 2.08, 2.04, 2.0] # V
AmpMax   = [1.92, 1.92, 1.96, 2.0, 2.0, 2.04, 2.04, 2.0, 1.96] # mV
RiseTime = [3.0, 3.0, 2.9, 3.0, 2.9, 3.0, 3.1, 3.0, 2.9] # ns
FallTime = [85.0, 90.1, 81.6, 96.8, 101.0, 118.6, 99.8, 95.2, 81.5] # ns

# %%
'''Data of the Z position scan 3 (zoom into 2000 to 4000 range)'''

Z =        np.linspace(2000, 4000, 11) # um
AmpMean  = [468, 481, 494, 500, 502, 503, 500, 492, 481, 472, 459] # mV
AmpPeak  = [2.0, 1.96, 1.92, 1.96, 2.0, 2.04, 2.04, 2.08, 2.04, 2.08, 2.08] # V
AmpMax   = [2.0, 1.96, 1.92, 1.96, 2.0, 2.04, 2.04, 2.04, 2.04, 2.04, 2.04] # mV
RiseTime = [2.9, 3.2, 3.1, 3.2, 2.9, 3.0, 3.0, 3.1, 3.1, 3.1, 3.1] # ns
FallTime = [100.9, 119.4, 119.6, 121, 118.9, 113.5, 101.3, 100.6, 112.0, 100.4, 100.0] # ns

# %%
# plt.scatter(Z[2:-3], AmpMean[2:-3])
plt.scatter(Z, AmpMean)
plt.xlabel("Z position [um]")
plt.ylabel("Mean amplitude [mV]")
plt.title("Lens Z position vs mean amplitude")
plt.grid()
plt.show()

# %%
ZX = [
    [-3000, -2900, -2800, -2700, -2600, -2500, -2400, -2300, -2200, -2100,
     -2000, -1900, -1800, -1700, -1600, -1500, -1400, -1300, -1200] + list(np.linspace(-1180, -900, 15)), 
    [],
     ]
AmpMean  = [
    [509, 500, 505, 509, 505, 491, 500, 502, 499, 487,
     489, 490, 484, 471, 467, 464, 448, 426, 417] + 
    [408, 407, 401, 394, 395, 385, 368, 346, 313, ],
            ] # mV
AmpPeak  = [
    [2.04, 2.04, 2.04, 2.00, 2.04, 2.04, 2.04, 2.00, 2.00, 2.04,
     2.00, 1.96, 1.96, 2.00, 1.96, 1.92, 1.92, 1.92, 1.88, 
     1.80, 1.84, 1.92, 1.84, 1.80, 1.84, 1.92, 1.88, 1.60, ],
            ] # V
AmpMax   = [
    [2.04, 2.04, 2.04, 2.00, 2.04, 2.04, 2.04, 2.00, 2.00, 2.04,
     2.00, 1.96, 1.96, 2.00, 1.96, 1.92, 1.92, 1.92, 1.88, 
     1.80, 1.84, 1.92, 1.84, 1.80, 1.84, 1.92, 1.88, 1.60, ],
            ] # V
RiseTime = [
    [3.0, 2.9, 3.0, 2.9, 3.0, 3.0, 3.0, 2.9, 2.9, 3.0,
     2.9, 3.2, 3.0, 2.9, 3.1, 3.2, 3.1, 3.0, 3.0, 
     3.0, 2.9, 3.0, 2.9, 3.0, 3.1, 3.1, 3.0, 2.8, 
     ],            
            ] # ns
FallTime = [
    [118.4, 101.9, 118.4, 118.4, 118.9, 102.4, 119.0, 118.8, 118.7, 103.0,
     103.0, 121.2, 120.2, 104.2, 122.4, 123.1, 123.5, 124.5, 125.3, 
     124.7, 108.3, 109.5, 108.6, 108.7, 108.7, 109.8, 110.3, 104.8, 
     ],
            ] # ns

# %%
plt.scatter(ZX[0][:len(AmpMean[0][:])], AmpMean[0][:])
plt.grid()
